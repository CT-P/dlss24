# %% [markdown]
# # Do always: mount first

# %%
#Import drive
from google.colab import drive
#Mount Google Drive
ROOT="/content/drive"
drive.mount(ROOT)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Clone github repository setup
# import join used to join ROOT path and MY_GOOGLE_DRIVE_PATH
# source: https://medium.com/p/5554d5824228
from os.path import join

# path to your project on Google Drive
MY_GOOGLE_DRIVE_PATH = 'MyDrive/dlss24'

# replace with your Github username
GIT_USERNAME = "CT-P"
# definitely replace with your
GIT_TOKEN = "your secret here"
# Replace with your github repository in this case we want
# to clone deep-learning-v2-pytorch repository
GIT_REPOSITORY = "dlss24"

PROJECT_PATH = join(ROOT, MY_GOOGLE_DRIVE_PATH)

# It's good to print out the value if you are not sure
print("PROJECT_PATH: ", PROJECT_PATH)

# %% [markdown]
# # Clone (do once)

# %%
# In case we haven't created the folder already; we will create a folder in the project path
# !mkdir "{PROJECT_PATH}"

#GIT_PATH = "https://{GIT_TOKEN}@github.com/{GIT_USERNAME}/{GIT_REPOSITORY}.git" this return 400 Bad Request for me
GIT_PATH = "https://" + GIT_TOKEN + "@github.com/" + GIT_USERNAME + "/" + GIT_REPOSITORY + ".git"
print("GIT_PATH: ", GIT_PATH)
# Out:
# PROJECT_PATH:  /content/drive/MyDrive/dlss24
# mkdir: cannot create directory ‘/content/drive/MyDrive/dlss24’: File exists
# GIT_PATH:  https://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@github.com/CT-P/dlss24.git

# %%
# %pwd
# Out:
# '/content'

# %%
#The class files will be here
# %cd {PROJECT_PATH}
# Out:
# /content/drive/MyDrive/dlss24

# %%
# %cd "{PROJECT_PATH}"    # Change directory to the location defined in project_path
# !git clone "{GIT_PATH}" # clone the github repository
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/dlss24 # Change directory to the location defined in project_path'
# /content/drive/MyDrive/dlss24
# Cloning into 'dlss24'...
# remote: Enumerating objects: 53, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 53 (delta 9), reused 38 (delta 3), pack-reused 0
# Receiving objects: 100% (53/53), 809.47 KiB | 3.80 MiB/s, done.
# Resolving deltas: 100% (9/9), done.

# %%
# %ls
# Out:
# 'Class 2 - Lab 28.04 - Basics .ipynb'         data/
# 'Class 2 - Lab 28.04 - Data Analysis.ipynb'   README.md

# %%
# %cd {GIT_REPOSITORY}
# Out:
# /content/drive/MyDrive/dlss24/dlss24

# %%
# !git branch
# Out:
# * main

# %% [markdown]
# # Do once (create your working branch)

# %%
#https://git-scm.com/book/en/v2/Git-Branching-Basic-Branching-and-Merging
# !git checkout -b workplace
# Out:
# Switched to a new branch 'workplace'

# %%
# !git branch
# Out:
#   main
# * workplace

# %% [markdown]
# # Connect Upstream

# %%
# !git remote add upstream https://github.com/udacity/deep-learning-v2-pytorch

# %%
#Unlike git pull, which automatically integrates the fetched changes into your current branch,
# git fetch only downloads the changes and updates the remote tracking branches. It does not modify your local branches or working directory.
# !git fetch upstream

# %%
# !git merge upstream/master

# %%
# push from origin (the online main original repo) to the master (in my git hub account)
# !git push origin master

# %%
#https://docs.github.com/en/pull-requests/collaborating-with-pull-requests/working-with-forks/configuring-a-remote-repository-for-a-fork
# !git remote -v
